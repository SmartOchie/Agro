# %% [markdown]
# <a href="https://colab.research.google.com/github/SmartOchie/Agro/blob/main/SIG742_FlowControl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# As a general practice, the Python style guide recommends using 4 white spaces for indenting a block rather than a tab. If you get indentation error message from Python, you will need to check your code carefully.

# %%
x = 15
if x % 2 == 0:
      print('%d is even' % x)
else:
      print('%d is odd' % x)
print('This is always printed')
# Out:
# 15 is odd
# This is always printed

# %% [markdown]
# The else-block in if statement is optional. If the else block is omitted, the statements in if-block are executed when the condition equal to True. Otherwise, the flow of execution continues to the statement after the if structure.

# %%
x = -2
if x < 0:
         print("The negative number %d is not valid here." % x)
print("This is always printed")
# Out:
# The negative number -2 is not valid here.
# This is always printed

# %% [markdown]
# What will be printed if the value of x is positive?
#
# If statements can also be nested within other if statements. Further if structure can either be nested in if-block or else-block. Here is an example with another if structure nested in an else-block, assuming we have two variables x and y. The code shows how we might decide how they are related to each other.

# %%
x = 10
y = 10
if x < y:
         print("x is less than y")
else:
         if x > y:
                  print("x is greater than y")
         else:
                  print("x and y must be equal")
# Out:
# x and y must be equal

# %% [markdown]
# Python also provides an alternative way to write nested if statement by using the keyword elif. The example above is equivalent to:

# %%
x = 10
y = 10
if (x < y):
            print("x is less than y")
elif (x > y):
            print("x is greater than y")
else:
            print("x and y must be equal")
# Out:
# x and y must be equal

# %% [markdown]
# elif is an abbreviation of else if. With above structure, each condition is checked in order. If one of them is True, the corresponding branch executes. Even if more than one condition is True, only the first True branch executes.
#
# There is no limit of the number of elif statements, but only a single final else statement is allowed. The else statement must be the last branch in the statement.

# %% [markdown]
# # **For statements**
#
# Computers are often used to automate repetitive tasks. Repeated execution of a sequence of statements is called iteration. Two language features provided by Python are **while** and **for** statement. We first take a look an example of **for** statement:

# %%
for name in ["Joe", "Amy", "Brad", "Angelina", "Zuki"]:
      print("Hi %s Please come to my party on Saturday!" % name)
# Out:
# Hi Joe Please come to my party on Saturday!
# Hi Amy Please come to my party on Saturday!
# Hi Brad Please come to my party on Saturday!
# Hi Angelina Please come to my party on Saturday!
# Hi Zuki Please come to my party on Saturday!

# %% [markdown]
# This example assumes that you'd like to send an invitation to a party to five of your friends. With all the name in the list, you can print a message for each friend.
#
# This is how the **for** statement works:
#
# 1. The names in the for statement are called **loop variables**, and the names in the square brackets are called **list** in Python. We will cover more details on list later on, for now, you just need to know how to use simple list in a for loop.
# 2 The second line in the program is the **loop body**. All the statements in the loop body are indented.
# 3. On each iteration of the loop, the loop variable is updated to refer to the next item in the list. In the above case, the loop body is executed 5 times, and each time name will refer to a different friend.
# 4. At the end of each execution of the body of the loop, Python returns to the for statement to handle the next item. This continues until there are no items left. Then program execution continues at the next statement after the loop body.
# One function commonly used in loop statement is range().
#
# Let us first have a look at the following example:

# %%
for i in [0, 1, 2, 3, 4 ]:
          print( 'The count is %d' % i)
# Out:
# The count is 0
# The count is 1
# The count is 2
# The count is 3
# The count is 4

# %% [markdown]
# Generating lists with a specific number of integers is a very common task, especially in **for** loop. For this purpose, Python provides a built-in **range()** function to generate a sequence of values. An alternative way of performing above counting using **range()** is as follows

# %%
i = 0
while (i < 6):
             print('The count is %d' % i)
             i = i + 1
print('Good bye!')
# Out:
# The count is 0
# The count is 1
# The count is 2
# The count is 3
# The count is 4
# The count is 5
# Good bye!

# %% [markdown]
# Notice **range(5)** generates a list of 5 values starting with 0 instead 1. In addition, 5 is not included in the list.

# %% [markdown]
# **While statements**
#
# The while statement provides a much more general mechanism for iteration. It allows you to repeatedly execute a block of statements as long as a condition is True.
#
# Similar to the if statement, the while statement uses a Boolean expression to control the flow of execution. The body of while will be repeated as long as the condition of boolean expression equal to True.
#
# Let us see how the previous counting program can be implemented by while statement.

# %%
i = 6
while i > 5 :
            print('The count is %d' % i)
            i = i + 1
print('Good bye!')
# Out:
# Streaming output truncated to the last 5000 lines.
# The count is 7500449
# The count is 7500450
# The count is 7500451
# The count is 7500452
# The count is 7500453
# The count is 7500454
# The count is 7500455
# The count is 7500456
# The count is 7500457
# The count is 7500458
# The count is 7500459
# The count is 7500460
# The count is 7500461
# The count is 7500462
# The count is 7500463
# The count is 7500464
# The count is 7500465
# The count is 7500466
# The count is 7500467
# The count is 7500468
# The count is 7500469
# The count is 7500470
# The count is 7500471
# The count is 7500472
# The count is 7500473
# The count is 7500474
# The count is 7500475
# The count is 7500476
# The count is 7500477
# The count is 7500478
# The count is 7500479
# The count is 7500480
# The count is 7500481
# The count is 7500482
# The count is 7500483
# The count is 7500484
# The count is 7500485
# The count is 7500486
# The count is 7500487
# The count is 7500488
# The count is 7500489
# ...

# %% [markdown]
# **Break statements**
#
# The break statement can be used to break out of a loop statement. It can be used both in while loop and for loops.
#
# An alternative way of programming the previous counting example using a break statement appears below.

# %%
i = 0
while True :
            print( 'The count is %d' % i)
            i = i + 1
            if i > 6:
                     break
print('Good bye!')
# Out:
# The count is 0
# The count is 1
# The count is 2
# The count is 3
# The count is 4
# The count is 5
# The count is 6
# Good bye!

# %% [markdown]
# In this program, we repeatedly printed the value of i as it increased by 1 each time. We then provided a special condition to stop the program by checking if i is greater than 6. If so, we break out of the loop and continue executing the statement after the loop - print('Good bye!').
#
# It is important to decide what the termination condition should be. It can be different in each loop.

# %% [markdown]
# Take a look at the Collatz Conjecture. Can you create a program that tests if a number ends in a 4 --> 2 --> 1 loop?

# %%
# Collatz sequence program

# Ask user to choose a number
n = int(input("Enter a number: "))

# Generate the sequence
while n != 1:
    print(n, end=" -> ")
    if n % 2 == 0:
        n = n // 2
    else:
        n = 3 * n + 1

# Print the last number (1)
print(1)
# Out:
# Enter a number: 100
# 100 -> 50 -> 25 -> 76 -> 38 -> 19 -> 58 -> 29 -> 88 -> 44 -> 22 -> 11 -> 34 -> 17 -> 52 -> 26 -> 13 -> 40 -> 20 -> 10 -> 5 -> 16 -> 8 -> 4 -> 2 -> 1
